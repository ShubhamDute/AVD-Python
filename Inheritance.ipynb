# %% [markdown]
# # Inheritance

# %%
class Person:

    def __init__(self, name: str, age: int):
        self.name = name
        self.age = age

    def introduce(self):
        print(f"My name is {self.name}")
        print(f"My age is {self.age}")

# %%
class Employee(Person):

    def __init__(self, name: str, age: int, company: str):
        super().__init__(name, age)
        self.company = company

    def work(self):
        print(f"I work at {self.company}")

# %%
p1 = Person(name="shubham", age=24) 
p1.name
# Out:
# 'shubham'

# %%
p1.age
# Out:
# 24

# %%
p1.introduce()
# Out:
# My name is shubham
# My age is 24

# %%
e1 = Employee(name="shubham",age=24, company="TCS")

# %%
e1.name
# Out:
# 'shubham'

# %%
e1.age
# Out:
# 24

# %%
e1.introduce()
# Out:
# My name is shubham
# My age is 24

# %%
e1.company
# Out:
# 'TCS'

# %%
e1.work()
# Out:
# I work at TCS

# %%
e1.introduce()
e1.work()
# Out:
# My name is shubham
# My age is 24
# I work at TCS

# %% [markdown]
# # Multilevel Inheritance

# %%
class Employee2:
    def __init__(self, emp_id: int, name: str):
        self.emp_id = emp_id
        self.name   = name

    def get_employee_info(self):
        print(f"Employee ID : {self.emp_id} and name : {self.name}")

# %%
class Manager(Employee2):

    def __init__(self, emp_id, name, dept):
        super().__init__(emp_id, name)
        self.dept = dept

    def get_dept(self):
        print(f"Department : {self.dept}")

# %%
class ProjectManager(Manager):

    def __init__(self, emp_id, name, dept, project):
        super().__init__(emp_id, name, dept)
        self.project = project

    def get_project(self):
        print(f"Project :{self.project}")

# %%
e1 = Employee2(emp_id=102,name="shubham")
type(e1)
# Out:
# __main__.Employee2

# %%
e1.emp_id
# Out:
# 102

# %%
e1.name
# Out:
# 'shubham'

# %%
e1.get_employee_info()
# Out:
# Employee ID : 102 and name : shubham

# %%
m1 = Manager(emp_id=101, name="shubham", dept="Data")
type(m1)
# Out:
# __main__.Manager

# %%
m1.get_dept()
# Out:
# Department : Data

# %%
m1.get_employee_info()
# Out:
# Employee ID : 101 and name : shubham

# %%
m1.get_employee_info()
m1.get_dept()
# Out:
# Employee ID : 101 and name : shubham
# Department : Data

# %%
pm1 = ProjectManager(emp_id=101, name="shubham", dept="data",project="building dashboard")

# %%
pm1.emp_id
# Out:
# 101

# %%
pm1.name
# Out:
# 'shubham'

# %%
pm1.dept
# Out:
# 'data'

# %%
pm1.project
# Out:
# 'building dashboard'

# %%
pm1.get_employee_info()
pm1.get_dept()
pm1.get_project()
# Out:
# Employee ID : 101 and name : shubham
# Department : data
# Project :building dashboard

# %% [markdown]
# # Multiple Inheritance
# 1. Multiple parent class
# 2. Single child class

# %%
class BaseSalary:

    def __init__(self, base_salary: float):
        self.base_salary = base_salary

    def get_salary(self):
        return self.base_salary

# %%
class Bonus:

    def __init__(self, bonus_per: float):
        self.bonus_per = bonus_per

    def get_bonus_amt(self, salary: float):
        return (self.bonus_per /100) * salary

# %%
class Tax:

    def __init__(self, tax_per: float):
        self.tax_per = tax_per

    def calculate_tax(self, gross_salary: float):
        return (self.tax_per / 100) * gross_salary

# %%
class TotalSalary(BaseSalary, Bonus, Tax): 
 
    def __init__(self, base_salary: float, bonus_per: float, tax_per: float):
        BaseSalary.__init__(self, base_salary) 
        Bonus.__init__(self, bonus_per)
        Tax.__init__(self, tax_per)

    def calculate_total_salary(self):
        bonus_amt = Bonus.get_bonus_amt(self, self.base_salary)
        print(f"Bonus Amount : {bonus_amt}")
        print(f"Base Salary : {self.base_salary}")
        sal_after_bonus = self.base_salary + bonus_amt
        print(f"Salary After Bonus : {sal_after_bonus}")
        tax = Tax.calculate_tax(self, sal_after_bonus)
        print(f"Tax Calculated : {tax}")
        amt = sal_after_bonus - tax
        print(f"Final Amount : {amt}")
        return amt

# %%
t  = TotalSalary(base_salary=25000, bonus_per=15, tax_per=10)

# %%
t.base_salary
# Out:
# 25000

# %%
t.bonus_per
# Out:
# 15

# %%
t.tax_per
# Out:
# 10

# %%
final_salary = t.calculate_total_salary()
# Out:
# Bonus Amount : 3750.0
# Base Salary : 25000
# Salary After Bonus : 28750.0
# Tax Calculated : 2875.0
# Final Amount : 25875.0

# %% [markdown]
# # Hirarchical Inheritance

# %%
class Shape:

    def __init__(self):
        pass

    def perimeter(self):
        pass

    def area(self):
        pass

    def print_perimeter_and_area(self):
        print(f"Perimeter : {self.perimeter()}")
        print(f"Area : {self.area()}")

# %%
class Rectangle(Shape):

    def __init__(self, width, height):
        super().__init__()
        self.width = width
        self.height = height

    def perimeter(self):
        return 2 * (self.width + self.height)


    def area(self):
        return self.width * self.height

# %%
import math
class Circle(Shape):


    def __init__(self, radius: float):
        super().__init__()
        self.radius = radius
    
    def perimeter(self):
        return 2 * math.pi * self.radius
    
    def area(self):
        return math.pi * (self.radius ** 2)

# %%
r1 = Rectangle(width=19, height=10)
type(r1)
# Out:
# __main__.Rectangle

# %%
r1.perimeter()
# Out:
# 58

# %%
r1.area()
# Out:
# 190

# %%
r1.print_perimeter_and_area()
# Out:
# Perimeter : 58
# Area : 190

# %%
c1 = Circle(radius=101) 
c1.radius
# Out:
# 101

# %%
c1.perimeter()
# Out:
# 634.6017160251382

# %%
c1.area()
# Out:
# 32047.38665926948

# %%
c1.print_perimeter_and_area()
# Out:
# Perimeter : 634.6017160251382
# Area : 32047.38665926948

# %%
shapes = [
    Circle(radius=22),
    Rectangle(width=40, height=20),
    Rectangle(width=50, height=25),
    Circle(radius=21)
]

# %%
for s in shapes:
    print(type(s))
    s.print_perimeter_and_area()
    print("================")
# Out:
# <class '__main__.Circle'>
# Perimeter : 138.23007675795088
# Area : 1520.53084433746
# ================
# <class '__main__.Rectangle'>
# Perimeter : 120
# Area : 800
# ================
# <class '__main__.Rectangle'>
# Perimeter : 150
# Area : 1250
# ================
# <class '__main__.Circle'>
# Perimeter : 131.94689145077132
# Area : 1385.4423602330987
# ================
